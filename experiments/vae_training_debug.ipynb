# %%
# !git clone https://github.com/javiuv/GenNN-InverseMicro
# %cd GenNN-InverseMicro
# !git checkout feature/dataset-preprocessing
# Out:
# Cloning into 'GenNN-InverseMicro'...
# remote: Enumerating objects: 228, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 228 (delta 109), reused 193 (delta 75), pack-reused 0 (from 0)
# Receiving objects: 100% (228/228), 4.70 MiB | 19.65 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# /content/GenNN-InverseMicro
# Branch 'feature/dataset-preprocessing' set up to track remote branch 'feature/dataset-preprocessing' from 'origin'.
# Switched to a new branch 'feature/dataset-preprocessing'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision tqdm pyyaml scikit-image

# %%
# !cat _config/vae_training.yaml
# Out:
# # GenNN-InverseMicro: VAE Configuration File for training
#
# model_params:
#   input_channels: 3
#   latent_dim: 64
#   hidden_dims: [32, 64, 128, 256]
#   input_size: 96
#
# training_params:
#   batch_size: 16
#   epochs: 20
#   learning_rate: 0.0001
#   beta: 0.00005  # Beta-VAE weight
#   device: "cuda" # or "cpu"
#
# pth_path: "models/vae/best_vae.pth"

# %%
import os

train_clean = "/content/drive/MyDrive/pcam_project/processed_denoising_final/train/clean"
print("Exists:", os.path.exists(train_clean))
print("Num files:", len(os.listdir(train_clean)))
# Out:
# Exists: True
# Num files: 10000

# %%
# !python main_train_vae.py
# Out:
# Number of training images: 10000
#   0% 0/20 [00:00<?, ?it/s]Epoch 1/20 | loss=12968406.0215 | recon=12967988.0244 | kl=8359652.3864
#   5% 1/20 [05:00<1:35:01, 300.07s/it]Epoch 2/20 | loss=9170914.0830 | recon=9170604.7500 | kl=6186783.0879
#  10% 2/20 [05:41<44:18, 147.68s/it]  Epoch 3/20 | loss=8689789.9258 | recon=8689443.4443 | kl=6929606.3584
#  15% 3/20 [06:22<28:04, 99.07s/it] Epoch 4/20 | loss=8479101.7129 | recon=8478724.5469 | kl=7543513.0576
#  20% 4/20 [07:03<20:18, 76.15s/it]Epoch 5/20 | loss=8369684.4014 | recon=8369277.0371 | kl=8147137.5801
# Checkpoint saved at /content/drive/MyDrive/pcam_project/models/vae/vae_epoch_5.pth
#  25% 5/20 [07:44<15:52, 63.48s/it]Epoch 6/20 | loss=8327873.4951 | recon=8327436.8691 | kl=8732518.8545
#  30% 6/20 [08:25<13:03, 55.94s/it]Epoch 7/20 | loss=8280737.9570 | recon=8280283.2529 | kl=9094089.4316
#  35% 7/20 [09:06<11:02, 50.97s/it]Epoch 8/20 | loss=8248544.9258 | recon=8248074.7285 | kl=9404147.7275
# ...

# %%
# !ls /content/drive/MyDrive/pcam_project/models/vae
# !ls /content/drive/MyDrive/pcam_project/configs
# Out:
# best_vae.pth	  vae_epoch_15.pth  vae_epoch_5.pth
# vae_epoch_10.pth  vae_epoch_20.pth
# vae_training_used.yaml
